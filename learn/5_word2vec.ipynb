# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'of', 'as', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.189685
# Nearest to zero: britannia, vanderbilt, galeon, social, phylogenetic, geeks, needed, kris,
# Nearest to may: guerrilla, shutdown, oriented, resistivity, desserts, low, awoke, artificial,
# Nearest to an: rooks, deferred, wheelchair, establishing, tinctures, dyadic, methamphetamine, jealous,
# Nearest to six: spite, stuka, nootka, slayton, shires, facilities, ewes, kurds,
# Nearest to th: snell, google, abductions, hakim, expression, russa, imitating, fln,
# Nearest to into: pedal, transmit, meitnerium, tempos, miocene, utopia, numeral, elphinstone,
# Nearest to all: saxe, sinus, kinetics, untouched, amaterasu, bedside, titles, pemberton,
# Nearest to over: invitational, unexplored, mf, wharf, ophelia, winnings, christ, von,
# Nearest to were: dietrich, crafts, conjunction, systematized, neorealism, civilization, coulomb, directorial,
# Nearest to after: streetcars, fighter, oasis, peak, hammersmith, concluded, lanphier, neighbourhood,
# Nearest to has: oxley, generated, industrial, aborigines, compare, volo, merci, confessing,
# Nearest to however: battlefield, topol, saved, emma, ssc, lemass, remainders, unselfish,
# Nearest to which: reputation, services, fincher, diatessaron, cccc, lightsabers, bounding, bristles,
# Nearest to world: edgard, coining, operate, seminars, melbourne, cellists, sighting, digitization,
# Nearest to in: minimize, ripe, polaris, executor, arranged, ineffectual, hasdrubal, exhibited,
# Nearest to this: rsc, ramesh, resounding, completes, mohamed, jahangir, aron, contour,
# Average loss at step 2000: 4.359468
# Average loss at step 4000: 3.864595
# Average loss at step 6000: 3.788118
# Average loss at step 8000: 3.690114
# Average loss at step 10000: 3.608997
# Nearest to zero: seven, nine, eight, five, six, three, four, two,
# Nearest to may: can, would, connections, will, artificial, infantry, could, looming,
# Nearest to an: the, outright, militant, mutants, rooks, trey, its, scans,
# Nearest to six: eight, five, seven, four, three, nine, zero, two,
# Nearest to th: snell, abductions, two, eight, three, four, imitating, six,
# Nearest to into: with, meitnerium, schirra, numeral, sliders, niles, orion, placed,
# Nearest to all: economy, installer, illuminated, uncontrollably, these, version, my, delay,
# Nearest to over: invitational, irian, mf, christ, alliteration, rifling, like, tatra,
# Nearest to were: are, was, have, gateless, had, rhythmic, luckily, flag,
# Nearest to after: with, festus, garber, entangled, toil, fighter, streetcars, as,
# Nearest to has: was, have, had, is, sintering, industrial, satirizing, recovered,
# Nearest to however: battlefield, topol, duckworth, unselfish, saved, ssc, emptied, nlm,
# Nearest to which: this, it, that, juventus, also, who, lethal, scriptures,
# Nearest to world: krylov, vogel, timer, coining, sighting, cellists, alcatraz, melbourne,
# Nearest to in: on, of, with, at, executor, from, and, obfuscated,
# Nearest to this: it, which, the, that, resounding, quantitative, a, their,
# Average loss at step 12000: 3.603516
# Average loss at step 14000: 3.568724
# Average loss at step 16000: 3.406866
# Average loss at step 18000: 3.455988
# Average loss at step 20000: 3.544939
# Nearest to zero: six, five, seven, eight, four, three, nine, two,
# Nearest to may: can, would, will, could, connections, might, must, brassiere,
# Nearest to an: militant, mutants, composes, bromwich, dyadic, rooks, fai, trey,
# Nearest to six: four, seven, eight, five, nine, three, zero, two,
# Nearest to th: snell, maratha, five, abductions, two, four, google, reported,
# Nearest to into: from, meitnerium, niles, with, fuerza, normalized, numeral, on,
# Nearest to all: these, many, several, uncontrollably, economy, rochelle, nonnegative, some,
# Nearest to over: irian, invitational, like, tatra, mf, pharmacological, alliteration, auld,
# Nearest to were: are, was, had, have, gateless, by, when, been,
# Nearest to after: before, during, from, totaled, when, entangled, festus, bed,
# Nearest to has: had, have, was, sintering, is, satirizing, kansas, recovered,
# Nearest to however: but, although, battlefield, which, volga, charity, centimes, ssc,
# Nearest to which: this, who, that, it, also, there, but, what,
# Nearest to world: krylov, zhejiang, hickory, vogel, coining, manchurian, timer, crosstown,
# Nearest to in: on, at, during, with, anarchistic, from, executor, and,
# Nearest to this: which, it, the, a, that, his, subfield, megatokyo,
# Average loss at step 22000: 3.502654
# Average loss at step 24000: 3.488013
# Average loss at step 26000: 3.484605
# Average loss at step 28000: 3.480492
# Average loss at step 30000: 3.503286
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to may: can, would, could, will, must, might, should, connections,
# Nearest to an: militant, mutants, dyadic, grade, trey, trades, mckee, spinoff,
# Nearest to six: four, eight, seven, five, nine, three, two, zero,
# Nearest to th: rd, two, six, maratha, four, upholds, one, abductions,
# Nearest to into: from, niles, meitnerium, fuerza, on, in, normalized, with,
# Nearest to all: these, many, several, some, uncontrollably, my, nonnegative, philological,
# Nearest to over: irian, invitational, when, latest, mf, root, alliteration, robeson,
# Nearest to were: are, was, have, had, while, been, niue, is,
# Nearest to after: before, when, during, from, totaled, khanate, for, ncia,
# Nearest to has: had, have, is, was, sintering, satirizing, artisans, having,
# Nearest to however: but, although, charity, volga, unselfish, spectrometry, did, relinquish,
# Nearest to which: this, that, also, it, what, who, there, these,
# Nearest to world: office, krylov, nfl, conceptual, manchurian, hickory, gleichschaltung, vogel,
# Nearest to in: at, during, on, since, of, executor, calcio, until,
# Nearest to this: which, it, there, that, malting, he, resilient, some,
# Average loss at step 32000: 3.497927
# Average loss at step 34000: 3.494303
# Average loss at step 36000: 3.451600
# Average loss at step 38000: 3.303434
# Average loss at step 40000: 3.425791
# Nearest to zero: seven, five, nine, eight, six, four, three, two,
# Nearest to may: can, would, will, could, must, might, should, cannot,
# Nearest to an: composes, mutants, bromwich, mckee, dyadic, militant, jolie, spinoff,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to th: rd, maratha, bc, upholds, vaccinations, mg, five, abductions,
# Nearest to into: from, niles, through, fuerza, meitnerium, normalized, up, carriages,
# Nearest to all: both, nonnegative, several, many, ekam, these, breakbeats, patriarch,
# Nearest to over: when, alliteration, latest, around, invitational, rewritable, irian, refrigerator,
# Nearest to were: are, was, have, had, while, been, be, when,
# Nearest to after: before, during, when, while, evangelists, totaled, ncia, calcio,
# Nearest to has: had, have, was, is, sintering, satirizing, vec, artisans,
# Nearest to however: but, although, that, charity, did, though, time, since,
# Nearest to which: this, that, also, it, often, who, usually, there,
# Nearest to world: nfl, krylov, vogel, office, coining, yeomen, conceptual, sorbian,
# Nearest to in: of, during, since, from, at, controversially, within, for,
# Nearest to this: which, it, that, the, there, some, malting, any,
# Average loss at step 42000: 3.432060
# Average loss at step 44000: 3.452809
# Average loss at step 46000: 3.449919
# Average loss at step 48000: 3.355264
# Average loss at step 50000: 3.383498
# Nearest to zero: five, eight, four, nine, seven, six, three, two,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to an: militant, mutants, composes, wcl, dyadic, deferred, trey, bromwich,
# Nearest to six: eight, seven, four, nine, five, three, two, one,
# Nearest to th: bc, rd, six, nd, upholds, maratha, mg, eight,
# Nearest to into: from, through, niles, on, around, meitnerium, fuerza, diverges,
# Nearest to all: both, many, remote, each, several, various, some, kroeber,
# Nearest to over: latest, around, irian, usda, alliteration, on, invitation, rewritable,
# Nearest to were: are, was, have, had, wilmut, be, gateless, origination,
# Nearest to after: before, when, during, while, totaled, mitchell, until, although,
# Nearest to has: had, have, is, was, satirizing, having, sintering, artisans,
# Nearest to however: but, although, though, while, that, when, since, did,
# Nearest to which: this, that, who, also, what, these, usually, but,
# Nearest to world: nfl, exodus, office, title, prover, empiricists, krylov, vogel,
# Nearest to in: during, of, within, since, on, from, at, hird,
# Nearest to this: which, it, there, the, that, he, hwa, fix,
# Average loss at step 52000: 3.438356
# Average loss at step 54000: 3.422765
# Average loss at step 56000: 3.435513

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
