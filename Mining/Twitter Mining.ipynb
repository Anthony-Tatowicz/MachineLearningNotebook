# %%
import twitter
import json


CONSUMER_KEY = 'q5F2YSrNrqMnOlauYXhLrtaE7'
CONSUMER_SECRET ='PIUORKHVZVYje8NqWEGkYbmZzYuOMAgaKyf43xZUuIEnFwos6I'
OAUTH_TOKEN = '2765643592-cAwtuMy6YsRBYamPF1NDILPy3i9m6T5hcrnirHH'
OAUTH_TOKEN_SECRET = 'eUbUjDhho3ErCcf6aa4tiiUR6XihzOcRvWcKdwiEFVUjs'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)


twitter_api = twitter.Twitter(auth=auth)

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977


world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print(json.dumps(world_trends, indent=1))
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ],
#   "as_of": "2016-04-03T02:57:39Z",
#   "trends": [
#    {
#     "name": "#AmorESexo",
#     "url": "http://twitter.com/search?q=%23AmorESexo",
#     "promoted_content": null,
#     "tweet_volume": 23170,
#     "query": "%23AmorESexo"
#    },
#    {
#     "name": "#WWEHOF",
#     "url": "http://twitter.com/search?q=%23WWEHOF",
#     "promoted_content": null,
#     "tweet_volume": 101630,
#     "query": "%23WWEHOF"
#    },
#    {
#     "name": "#FinalFour",
#     "url": "http://twitter.com/search?q=%23FinalFour",
#     "promoted_content": null,
#     "tweet_volume": 300638,
#     "query": "%23FinalFour"
#    },
#    {
#     "name": "GO DIRECTIONERS GO",
#     "url": "http://twitter.com/search?q=%22GO+DIRECTIONERS+GO%22",
#     "promoted_content": null,
#     "tweet_volume": 2536174,
#     "query": "%22GO+DIRECTIONERS+GO%22"
#    },
#    {
#     "name": "#FicaMunik",
# ...

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)
# Out:
# {'#MostRequestedLive', '#WWEHOF', 'UNITE 5SOSFAM', '#glaadawards', '#MyTotallyBelievableAlibi', 'Stamkos', '#WhatIdWishFor', 'GO DIRECTIONERS GO', '#FinalFour', '#JFCShawnMendes', '#IndyCar', '#DeadlyPossessions'}
